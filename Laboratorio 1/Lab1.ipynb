# %% [markdown]
# <h1><center>Laboratorio 1: Git 👾</center></h1>
#
# <center><strong>MDS7202: Laboratorio de Programación Científica para Ciencia de Datos - Primavera 2024</strong></center>

# %% [markdown]
# ### Cuerpo Docente:
#
# - Profesores: Ignacio Meza, Sebastián Tinoco
# - Auxiliar: Eduardo Moya
# - Ayudantes: Nicolás Ojeda, Melanie Peña, Valentina Rojas

# %% [markdown]
# ### Equipo:
# - Javiera Donoso
# - Belén Órdenes

# %% [markdown]
# ### **Link de repositorio de GitHub:** [Repositorio](https://github.com/javieradonoso/Repositorio-MDS7202)

# %% [markdown]
# ## Reglas:
#
# - **Grupos de 2 personas**
# - Fecha de entrega: 6 días de plazo con descuento de 1 punto por día. Entregas Jueves a las 23:59.
# - Instrucciones del lab el viernes a las 16:15 en formato online. Asistencia no es obligatoria.
# - <u>Prohibidas las copias</u>. Cualquier intento de copia será debidamente penalizado con el reglamento de la escuela.
# - Tienen que subir el laboratorio a u-cursos y a su repositorio de github. Labs que no estén en u-cursos no serán revisados. Recuerden que el repositorio también tiene nota.
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Pueden usar cualquier material del curso que estimen conveniente.

# %% [markdown]
# ## Objetivos del lab:
#
#
# - Conocer los elementos básicos que conformar `Git`
# - Clonar repositorios
# - Identificar ramas de un repositorio
# - Reconocer y solucionar problemas entre ramas
# - Subir cambios a un repositorio

# %% [markdown]
# ## Parte 1: Conocimiento Teórico (2.5 pts)
#
# <p align="center">
#   <img src="https://cdn.thedesigninspiration.com/wp-content/uploads/sites/3/2019/04/macintosh-hdusersbrittanyloefflerdownloadsanig-1.gif" width="350">
# </p>

# %% [markdown]
# Responda las siguientes preguntas (0.2 pts c/u):
#
# 1. ¿Qué es `Git` y cómo se relaciona con el control de versiones?
#
# 2. Nombre y explique 3 diferencias entre `Git` y `Github`.
#
# 3. ¿Qué es un `hash` y cómo se representa en un `commit`? De un ejemplo.
#
# 4. ¿Que elementos componen a la estructura de datos de `Git`?
#
# 5. ¿Que comandos de `Git` sirven para crear un repositorio y hacer seguimiento a cambios en los archivos?

# %% [markdown]
# <code>Respuestas:</code>
#
# 1. `Git` es un Sistema de Control de Versiones Distribuido (DVCS), lo cual es un sistema permite registrar los cambios realizados en un archivo (o varios) a lo largo del tiempo. Por lo tanto, `Git` permite rastrear, gestionar y trabajar de manera distribuida, es decir, que cada usuario tiene una copia completa del repositorio, lo cual es un conjunto de carpetas y archivos en el que se almacena el código de un proyecto más el historial de cambios. Cabe mencionar que este es un software.
#
# 2. Diferencias entre `Git` y `GitHub`:
# - En primer lugar, `Git` es un sistema de control de versiones distribuido (DVCS), como se mencionó anteriormente, en cambio, `GitHub` es un servicio de alojamiento en web basado en `Git`. Este proporciona un espacio en la nube para subir repositorios `Git`.
# - En segundo lugar, `Git` se usa principalmente con líneas de comandos en una terminal. En cambio, `GitHub` otorga una interfaz gráfica web que facilita la colaboración y gestión de proyectos en equipo.
# - En tercer lugar, `Git` es un software que se centra en las operaciones básicas de control de versiones, como commits, merges y creación de ramas, y crea un repositorio local para trackear los cambios locales. En cambio, `GitHub`, que entrega funcionalidades de `Git`, añade funcionalidades adicionales como pull request y herramientas colaborativas.
#
# 3. Un `Hash` es una representación única de un elemento dentro del sistema y tiene 40 caracteres. Este puede apuntar a un blob, un commit o un árbol. `Git` utiliza el hash `SHA1`. En otras palabras, un `hash` es un identificador único y permanente de cada elemento del repositorio, incluso si el contenido es similar.
# Cuando se usa un `commit` en `Git`, se genera un `hash` único que identifica a este commit específico. Gracias a este `hash`, `Git` puede rastrear exactamente los cambios que se han realizado en el proyecto en cualquier punto del historial. Ejemplo: el `hash` del `commit` es el identificador único de este.
# ```
# Commit: 47e1ab28f9d219f07f4e6c8b13a993c587a191dc
# Author: Belen Ordenes <belenordenes0705@gmail.com
# Date:   Mon Aug 20 12:34:56 2024 -0300
# ```
#
#
# 4. El núcleo de `Git` es una estructura de datos *key-value* y en él, son guardadas cada una de las rutas y archivos del repositorio. Los elementos que componen a la estructura de datos de `Git` son:
# - `Blob`: es una de las unidades básicas de almacenamiento en `Git` que guarda todo el contido de un archivo. Cuando un objeto es modificado, un nuevo blob almacenará el archivo completo con todos sus nuevos cambios en cierto momento.
# - `Tree` (árbol): representa directorios para `blobs` y más árboles y siempre habrá uno en la raíz apuntando al àrbol que contiene otros objetos.
# - `Commit`: es un "snapshots" (capturas) en el historial que registran y consolidan los cambios en un momento específico. Cada commit está identificado por un `hash` único y también almacena más información como el autor, el mensaje (o desccripción) y fecha.
# - `Hash`: es una cadena de 40 caracteres que permite identificar a cada elemento en la estructura de datos de `Git` (blobs, trees, commits).
#
# 5. Los comandos que permiten crear repositorios y hacer seguimiento de los cambios en los archivos son:
# - `>> git init nombre-del-repo`: inicializa un repositorio `Git` desde cero.
# - `>> git clone /ruta-al-repo.git`: permite clonar un repositorio, es decir, copiar un repositorio al almacenamiento local desde algún servidor, incluyendo su historial.
# - `>> git status`: este comando muestra el estado actual del repositorio.  Es una clave para saber los cambios realizados y cuáles están listos para ser commit.
# - `>> git add`: se usa para añadir archivos, carpetas o todo al *staging area*, preparando estos para ser incluidos en el próximo `commit`.
# - `>> git commit -m "mensaje"`:  crea un commit con los archivos/carpetas que han sido añadidos a la *staging area*. Como se mencionó, el `commit` captura un snapshot del estado actual del proyecto y lo almacena en el historial de `Git`.

# %% [markdown]
# Responda si las siguientes afirmaciones son Verdaderas (V) o Falsas (F). Justifique en **cualquiera** de los casos (0.2 pts c/u):
#
#
# 6. `Git` siempre resuelve automáticamente los problemas de lineas al hacer merge entre diferentes ramas.
# 7. Ejecutar `git pull` sobre un repositorio es equivalente a ejecutar `git clone`.
# 8. `git status` genera los mismos resultados que `git log`.
# 9. En `Git` es posible deshacer cambios y volver a versiones anteriores del código.
# 10. El comando `git commit` se utiliza para enviar cambios al repositorio remoto.

# %% [markdown]
# <code>Respuestas:</code>
# 6. Falso. En git si existen conflictos entre versiones de documentos que están en distintas ramas al tratar de hacer un merge, esto ocurre cuando existen diferencias en algunos bloques de código que existe en un archivo, pero no existe en el otro. Para poder solucionarlo Git le pide al usuario resolver dichos conflictos,o también puede mantener los cambios solo de una rama.
#
# 7. Falso. <code>git clone</code> crea una copia local de un repositorio remoto, mientras que <code> git pull </code> actualiza un repositorio local a partir de los cambios realizados en el repositorio remoto.
#
# 8. Falso. <code> git status </code> es un comando que muestra el estado actual del repositorio local en comparación al repositorio remoto y muestra los archivos modificados, los no rastreados, los que están en stagin area, entre otras. Por otro lado, <code> git log </code> es un comando que muestra y verifica los commits del historial del repositorio de manera cronológica, además muestra el hash, y la persona que lo creó en conjunto con la fecha.
#
# 9. Verdadero. Dentro de Git existen varios comandos que permiten deshacer los cambios realizados y volver a versiones anteriores, como por ejemplo, <code> git checkout hash</code> que actualiza el repositorio local para que coincida con el respositorio del commit de dicho hash. Otro comando es <code> git revert</code> el cual revierte los commits previos y se lo aplica a la rama que corresponde, y con ello se deshacen los cambios sin la necesidad de eliminar el historial.
#
# 10.  Falso. <code> git commit </code> permite guardar los cambios realizados en el stagin area de Git, y luego son enviados al repositorio remoto utilizando el comando <code> git push </code>

# %% [markdown]
# Por último, investigue y comente con sus palabras para qué sirven los siguientes comandos:
#
# 11. `git stash` (0.25 puntos)
# 12. `git reset`. ¿Cuál es la diferencia de este comando con `git revert`?. (0.25 puntos)

# %% [markdown]
# `Respuestas:`
# 11. El comando `git stash` almacena temporalmente ( guarda en un *stash*) los cambios hechos en el código sin tener que comprometerlos a un `commit`. En otras palabras, permite guardar momentaneamente los cambios en un archivo, que por ejemplo aún no está terminado, para poder trabajar en otros o hacer otros cambios en el repositorio. Sirve cuando aún no está listo para hacer un `commit` y se requiere hacer otros cambios antes, permitiendo volver a lo que se tenía. Este también tiene la ventaja de mantener el área de trabajo limpia, ya que deja estos archivos en "espera" para terminarlos después y trabajar en algo más.
#
# 12. El comando <code> git resert</code> se usa para deshacer cambios en el historial de commits de un repositorio. Puede modificar el historial de los commits y con ello altera el historial para el resto de los usuarios. Por otro lado,<code>git revert</code> es una forma más segura de deshacer cambios, porque no altera el historial de commits. En lugar de borrar commits existentes, crea un nuevo commit que revierte los cambios introducidos por un commit anterior. La diferencia entre ambos es que <code> git resert</code>  es para reescribir el historial, mientras que <code>git revert</code> es para deshacer cambios sin alterar el historial.

# %% [markdown]
# ## Parte 2: Creando una presentación personal (1.5 pts)
#
# <p align="center">
#   <img src="https://media.tenor.com/arqlNu8gyJYAAAAC/cat-cat-jumping.gif" width="150">
# </p>

# %% [markdown]
# Para empezar a "*soltar las manos*" con `Git`, se les encomienda crear un repositorio con una presentación personal. El repositorio debe contener un breve resumen de quienes son ustedes, sus gustos, experiencias, y cualquier otro detalle interesante que ustedes consideren relevante.
#
# Para realizar esto, deben seguir los siguientes pasos:
#
# 1. Contar con una cuenta de github (1 por persona)
# 2. Crear un repositorio con su nombre de usuario
# 3. Vincular el repositorio a su ambiente local ¿Qué comando(s) me permiten hacer esto?
# 4. Crear un archivo `readme.md` con la información que ustedes deseen compartir.
# 5. Realizar `push` con los cambios generados
#
# A modo de ejemplo, pueden guiarse por esta *suculenta* [presentación](https://github.com/Mezosky)
#
# **Nota: Deben trabajar todos estos puntos desde su ambiente local**
#
# *Hint: Una buena opción es usar templates de presentación personal que encuentren en Google, como los que ofrece este [sitio](https://durgeshsamariya.github.io/awesome-github-profile-readme-templates/#/)*.
#
# **Entregable:**
#
# Enlace al repositorio con la presentación personal.
#
# IMPORTANTE: DEBEN ADJUNTAR UN ENLACE POR PERSONA

# %% [markdown]
# <code>Link Presentacion 1:</code> [Repositorio Javiera Donoso](https://github.com/javieradonoso/javieradonoso)
#
# <code>Link Presentacion 2:</code> [Repositorio Belén Órdenes](https://github.com/belenordenes/belenordenes-repo)

# %% [markdown]
# Para el paso 3 se utiliza el comando `clone` el cual permite clonar (copiar) un repositorio desde `GitHub` al almacenamieto local. Se ejecuta lo siguiente en el terminal:
#
# ```
# >> git clone ruta-al-repo.git
# ```

# %% [markdown]
# ## Parte 3: Trabajando sobre un repositorio externo (2 pts)
#
# <p align="center">
#   <img src="https://media.tenor.com/YXL-0SK15j4AAAAC/dance-animals.gif" width="300">
# </p>
#
# Tras muchos dolores de cabeza, un grupo de entusiastas académicos decidieron aprender sobre `Git` y así trabajar colaborativamente de forma más ordenada y eficiente. Después de una infinidad de intentos y aprender de sus errores "*a la mala*", los académicos lograron levantar un [repositorio](https://github.com/MDS7202/lab1) en `Github`. Usando el repositorio de los académicos, responda las siguientes preguntas (**incluya también los comandos en `Git` ocupados**):

# %% [markdown]
# 1. Clone el repositorio a su ambiente local. (0.25 pts)

# %% [markdown]
# <code>Respuesta:</code>
# Para clonar el repositorio en nuestro almacenamiento local se ocupó el comando:
# ```
# >> git clone https://github.com/MDS7202/lab1.git
# ```
# Esto imprime lo siguiente, confirmando que la copia se hizo correctamente:
# ```
# Clonando en 'lab1'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 14 (delta 4), reused 12 (delta 2), pack-reused 0 (from 0)
# Recibiendo objetos: 100% (14/14), listo.
# Resolviendo deltas: 100% (4/4), listo.
# ```

# %% [markdown]
# 2. Descomprima los archivos subidos con la tarea en U-cursos en la carpeta recién clonada de github. Una vez realizado esto, cree un archivo `.gitignore` con el cual omita la carpeta `videos` y los archivos con la extensión `.txt` exceptuando el archivo `171.txt` de la carpeta `texts`. (0.25 pts)

# %% [markdown]
# <code>Para esta pregunta usted deberá adjuntar el .gitignore creado en su repo.</code>
#
# El código del archivo `.gitignore` que fue adjuntado en nuestro repositorio dentro de la carpeta *Laboratorio 1* es el siguiente:
# ```
# # ignore video folder
# videos
#
# # ignore txt files in text folder
# texts/*.txt
#
# # don't ignore text 171.txt
# !texts/171.txt
# ```

# %% [markdown]
# 3. Inspeccione brevemente el repositorio: ¿Cual es el objetivo del proyecto? Explique brevemente la estructura del proyecto, asi como también cada elemento que lo conforma. (0.25 pts)

# %% [markdown]
# <code>Respuesta:</code>
#
# El repositorio está compuesto por 3 archivos:
# - `README.md`: inicio del repositorio donde describe: "Proyecto para emular los sonidos de animales"
# - `animales.py`: define una función `animales` que recibe un animal (input), revisa las condiciones y retorna el "sonido" que hace para perro ('guau'), gato ('miau') y fox (un video). Si el input no es ninguno de estos animales, retorna un error ('Animal no reconocido).
# - `main.py`: importa desde el archivo `animales.py` la función `animales`, pide el input (animal) y luego llama a la función.
#
# Además, tiene 3 ramas: `main` (default), `fix-ifs` y `new_features`. La rama principal tiene 3 commits. No tiene archivo `.gitignore`.

# %% [markdown]
# 4. Identifique los últimos cambios al repositorio, reconociendo las principales ramas de trabajo. ¿Son informativos los `commit` realizados? (0.25 pts)
# *Hint: Se recomienda usar los argumentos `all`, `graph` y `decorate`*

# %% [markdown]
# <code>Respuesta:</code>
#
# Primero se utiliza <code>git log</code> el cual nos muetra que en el último commits esta la función animales y luego la modificación de la función en otra rama llamada checkout.
#
# Las ramas encontradas a través del uso del comando  <code>git branch</code> se encuentra la principal <code>main</code>, una rama de nombre <code>checkout</code>. Luego, se utiliza el comando  <code>git branch -a</code> que encuentra 3 ramas remotas llamadas <code>fix-ifs</code>,  <code>new_features</code> y  <code>main</code>.
#
# Por último, cabe destacar que al realizar los comandos de `all`, `graph` y `decorate`, solo se muestra el código de cada commit y el comentario que va agregado, no se muestra que se está corrigiendo específicamente.

# %% [markdown]
# 5. Uno de los académicos se da cuenta que la rama principal de trabajo no se ejecuta correctamente para todos los argumentos. Señale y explique el error en el código e identifique a la persona que lo cometió usando `git blame` (0.25 pts)
#
# *Hint: Le puede ser útil esta [documentación](https://www.atlassian.com/es/git/tutorials/inspecting-a-repository/git-blame).*

# %% [markdown]
# <code>Respuesta:</code>
#
# Al ejecutar el archivo `main.py`, se observa que ocurre lo siguiente:
# ```
# >> .../python3 .../lab1/main.py
# Ingrese el animalito para saber que dice:
# gato
# miau
# Traceback (most recent call last):
#   File "/Users/javieradonosotabilo/lab1/main.py", line 6, in <module>
#     animales(animal)
#   File "/Users/javieradonosotabilo/lab1/animales.py", line 14, in animales
#     raise ValueError('animal no reconocido :(')
# ValueError: animal no reconocido 🙁
# ```
#
# Por lo tanto, se identifica un error, dado que al ingresar un animal válido ("gato"), se muestra de igual manera el `ValueError`. Como `main.py` importa la función de `animales.py`, el error se encuentra en este último.
#
# A continuación, se ejecuta `git blame animales.py` y se muestra el resultado de aplicar el comando:
# ```
# >> git blame animales.py
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300  1) def animales(input):
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300  2)
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300  3)     '''
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300  4)     Como hace el animalito?
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300  5)     '''
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300  6)
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300  7)     if input.lower() == 'gato':
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300  8)         print('miau')
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300  9)     if input.lower() == 'perro':
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300 10)         print('guau')
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300 11)     if input.lower() == 'fox':
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300 12)         print('https://www.youtube.com/watch?v=jofNR_WkoCE')
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300 13)     else:
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300 14)         raise ValueError('animal no reconocido :(')
# ```
#
# Se logra identificar que el error corresponde a la mala implementación de los `if` en `animales.py` y fue realizado por **mezosky** el 23/03/2023. Esto se debe a que, al usar puros `if`, la función revisa cada condición planteada para ver si el input coincide con alguno de los animales, sin embargo, el `else` corresponde solo al último `if`, por lo tanto, al ingresar "perro" o "gato" arroja el `ValueError`. Para arreglar esto, se deben usar `elif` luego del primer `if` para que revise la siguiente condición solo si no se cumple alguna de las primeras.

# %% [markdown]
# 6. Busque los siguientes `commit`:
#
# - `c8b1a62d7299552b0654f930d695b33109214111`
# - `362fe21ee44f53ee944cee4ba484600308f83d78`
# - `25543a3baf77292baf849726784ca005473acab1`
#
# ¿Qué diferencias existen entre cada uno? (0.25 pts)

# %% [markdown]
# <code>Respuesta:</code>
#
#
# Primero, se revisan todos los commit utilizando `git log --all`. Luego, se revisaron los commit uno por uno utilizando el comando `git show (commit)`
#
# - El primer Commit agrega la función `animales` directamente en `main.py`. En este punto, cada condición en la función se evalúa de forma independiente usando `if` para cada posible valor de input (`gato`, `perro`, `fox`).
#
# - En el segundo commit se separa el proyecto en módulos, en donde la función `animales` fue movida de `main.py` a un nuevo archivo, `animales.py`. En `main.py`, la función `animales` ahora se importa desde `animales.py` usando `from animales import animales`, manteniendo la lógica de la aplicación pero mejorando la organización del código.
#
# - En el tercer commit Se optimizan las estructuras condicionales en la función `animales`. Se realizaron cambios en la estructura de la función `animales` en donde los `if` independientes fueron cambiadas a `elif` para que solo se evalúe una condición a la vez.
#
# En el siguiente recuadro se observa lo obtenido por cada commit utilizando
# Primero, se revisan todos los commit utilizando `git log --all`.
#
# ```
# commit c8b1a62d7299552b0654f930d695b33109214111
# Author: seba <stinoco@fen.uchile.cl>
# Date:   Wed Mar 22 17:28:19 2023 -0300
#
#     se agrega funcion
#
# commit 362fe21ee44f53ee944cee4ba484600308f83d78 (HEAD -> main, origin/new_features, origin/main, origin/HEAD)
# Author: mezosky <ignacio.meza@ug.uchile.cl>
# Date:   Thu Mar 23 21:47:34 2023 -0300
#
#     Se separa el proyecto en modulos
#
#
#
# commit 25543a3baf77292baf849726784ca005473acab1 (origin/fix-ifs)
# Author: Pablo Badilla <pbadilla.torrealba@gmail.com>
# Date:   Thu Mar 23 22:50:49 2023 -0300
#
#     fix ifs
#
# ```

# %% [markdown]
# 7. Realice una `merge` de la rama `fix-ifs` con la rama `main` y describa lo que ocurre. ¿Qué parte del código podría estar ocasionando esto? (0.25 pts)

# %% [markdown]
# <code>Respuesta:</code>
#
# Para realizar un `merge` de la rama `fix-ifs` con la rama `main` se ejecuta el comando `git merge` y se obtiene:
#
# ```
# >> git merge origin/fix-ifs main
# Auto-fusionando main.py
# CONFLICTO (contenido): Conflicto de fusión en main.py
# Fusión automática falló; arregle los conflictos y luego realice un commit con el resultado.
# ```
# Esto quiere decir que no fue posible realizar el `merge` entre las ramos. Esto se debe a que en la rama main, el archivo `main.py` importa la función `animales(input)` desde otro archivo. En cambio, en la rama *fix-ifs* la función `animales` se define dentro del mismo.

# %% [markdown]
# 8. Cree una rama nueva y proponga una solución al problema anterior, adjuntando el código corregido y señalando las líneas modificadas. (0.25 pts)

# %% [markdown]
# <code>Respuestas:</code>
#
# Primero se debe abortar el merge anterior utilizando el comando <code>git merge --abort</code>. Posteriormente, se deben realizar los siguientes pasos para la creación de una nueva rama:
# - Utilizando el comando <code>git branch</code> y luego le añadimos el nombre de la nueva rama, en nuestro caso debería quedar de la siguiente manera
# <code>git branch new-merge</code>.
# - Ahora para seguir trabajando, hay que cambiarse a la rama que creamos, para eso utilizamos el comando <code>git checkout new-merge</code>.
# - Posteriormente, utilizamos el archivo de <code>animales.py</code> para modificarlo de la siguiente manera:

# %%
# Nuevo Código corregido
def animales(input):

    '''
    Como hace el animalito?
    '''

    if input.lower() == 'gato':
        print('miau')
    ### línea original: if input.lower() == 'perro'
    elif input.lower() == 'perro': ### modificación: 'if' a 'elif'
        print('guau')
    ### línea original: if input.lower() == 'fox':
    elif input.lower() == 'fox': ### modificación: 'if' a 'elif'
        print('https://www.youtube.com/watch?v=jofNR_WkoCE')
    else:
        raise ValueError('animal no reconocido :(')

# %% [markdown]
# - Por último, se guardan los cambios y finalmente se realiza el <code>merge</code> con main, el cual se realiza exitosamente, ya que no hay conflictos entre ambas ramas.

# %% [markdown]
# ## Fin

# %% [markdown]
# Eso ha sido todo por ahora!! Esperamos que este laboratorio les haya gustado y servido para trabajar con `Git`. Recuerden los dias de plazo que tienen disponibles y que ante cualquier duda no duden en contactar al equipo docente.
#
# Nos vemos!!
#
# <p align="center">
#   <img src="https://media.tenor.com/OYLdav9k9LkAAAAd/kitty-cat.gif" width="350">
# </p>
